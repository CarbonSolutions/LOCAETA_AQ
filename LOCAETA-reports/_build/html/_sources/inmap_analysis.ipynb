# %% [markdown]
# ## 2. INMAP simulation results

# %% [markdown]
# First, let's run the python script that comes two sets of INMAP simulations, focused on the changes of PM2.5 and premature mortality by the emissions scenarios. Note that it generates several figures, which are saved in output directory.

# %%
# %run /Users/yunhalee/Documents/LOCAETA/LOCAETA_AQ/inmap_run_comparison.py
# Out:
# Warning 3: Cannot find header.dxf (GDAL_DATA is not defined)
# Processing LA_CCS - Base: /Users/yunhalee/Documents/LOCAETA/RCM/INMAP/inmap-1.9.6-gridsplit/outputs/base_nei2020/2020nei_output_run_steady.shp, Sensitivity: /Users/yunhalee/Documents/LOCAETA/RCM/INMAP/inmap-1.9.6-gridsplit/outputs/LA_CCS/2020nei_output_run_steady.shp
# The data is from an inmap_run output.
# 2.36% of the observations have mismatched signs for TotalPM25 and TotalPopD.
# The median absolute magnitude ratio (TotalPM25 / TotalPopD) is: 4.75
# Column Sums:
#  AsianD        -0.881438
# BlackD        10.915206
# LatinoD      -10.905064
# NativeD       -0.422220
# WhitNoLatD   -26.000025
# TotalPopD    -28.015269
# dtype: float64
# Area-Weighted Averages:
# NH3: 0.002203263976144202
# NOx: -0.005651640804275658
# SOA: 5.76719009747308e-06
# SOx: -0.0007859526102600703
# PNH4: 0.002885263821719131
# PNO3: -0.0005737859576627945
# PSO4: -0.003114379675798468
# PrimPM25: -0.0006689838537283581
# TotalPM25: -0.001466118475591441
# GeoJSON data for column 'TotalPopD' has been saved to '/Users/yunhalee/Documents/LOCAETA/github/LOCAETA/WebTool/Data/INMAP_TotalPopD_LA_CCS.json'.
# GeoJSON data for column 'TotalPM25' has been saved to '/Users/yunhalee/Documents/LOCAETA/github/LOCAETA/WebTool/Data/INMAP_TotalPM25_LA_CCS.json'.
# Processing LA_CCS_noNH3 - Base: /Users/yunhalee/Documents/LOCAETA/RCM/INMAP/inmap-1.9.6-gridsplit/outputs/base_nei2020/2020nei_output_run_steady.shp, Sensitivity: /Users/yunhalee/Documents/LOCAETA/RCM/INMAP/inmap-1.9.6-gridsplit/outputs/LA_CCS_noNH3/2020nei_output_run_steady.shp
# The data is from an inmap_run output.
# 2.36% of the observations have mismatched signs for TotalPM25 and TotalPopD.
# The median absolute magnitude ratio (TotalPM25 / TotalPopD) is: 4.75
# Column Sums:
#  AsianD         -4.808422
# BlackD        -54.742148
# LatinoD       -27.529759
# NativeD        -1.195898
# WhitNoLatD   -125.796758
# TotalPopD    -217.942078
# dtype: float64
# Area-Weighted Averages:
# NH3: 0.0
# NOx: -0.005651640804275658
# SOA: 5.76719009747308e-06
# SOx: -0.0007859526102600703
# PNH4: 0.0
# PNO3: -0.0005737859576627945
# PSO4: -0.003114379675798468
# PrimPM25: -0.0006689838537283581
# TotalPM25: -0.004351382297245406
# GeoJSON data for column 'TotalPopD' has been saved to '/Users/yunhalee/Documents/LOCAETA/github/LOCAETA/WebTool/Data/INMAP_TotalPopD_LA_CCS_noNH3.json'.
# GeoJSON data for column 'TotalPM25' has been saved to '/Users/yunhalee/Documents/LOCAETA/github/LOCAETA/WebTool/Data/INMAP_TotalPM25_LA_CCS_noNH3.json'.

# %% [markdown]
# The figures below show the changes in air quality and premature mortality by the CCS technology applied over the LA state.  It shows the original emission scenario as well as the modified emission scenario where the NH3 emissions increase is excluded. As expected from the emissions analysis, the amine-based CCS technology increases NH3 gas concentration and NH4 portion of PM2.5, while the modified scenario shows air quality benefits for all species.

# %% [markdown]
# <table>
#   <tr>
#     <td>
#       <figure>
#         <figcaption>AQ changes by applying CCS tech over LA</figcaption>
#         <img src="/Users/yunhalee/Documents/LOCAETA/LOCAETA_AQ/outputs/model_analysis/LA_CCS_LA_CCS_impact_on_area_weighted_AQ.png" alt="" width="400"/>
#       </figure>
#     </td>
#     <td>
#       <figure>
#         <figcaption>AQ changes by applying CCS tech over LA without NH3</figcaption>
#         <img src="/Users/yunhalee/Documents/LOCAETA/LOCAETA_AQ/outputs/model_analysis/LA_CCS_noNH3_LA_CCS_impact_on_area_weighted_AQ.png" alt="" width="400"/>
#       </figure>
#     </td>
#   </tr>
#   <tr>
#     <td>
#       <figure>
#         <figcaption>Premature mortality changes by applying CCS tech over LA</figcaption>
#         <img src="/Users/yunhalee/Documents/LOCAETA/LOCAETA_AQ/outputs/model_analysis/LA_CCS_LA_CCS_impact_on_total_deaths.png" alt="" width="400"/>
#       </figure>
#     </td>
#     <td>
#       <figure>
#         <figcaption>Premature mortality changes by applying CCS tech over LA without NH3</figcaption>
#         <img src="/Users/yunhalee/Documents/LOCAETA/LOCAETA_AQ/outputs/model_analysis/LA_CCS_noNH3_LA_CCS_impact_on_total_deaths.png" alt="" width="400"/>
#       </figure>
#     </td>
#   </tr>
# </table>

# %% [markdown]
# The figures below shows the spatial distributions of the PM2.5 changes by the emission scenarios. The NH3 and NH4 increases are particularly high near some of the point-source facilities, not all facility. This leads to both the most postivie and the most negative benefits appeared in the LA state. Excluding NH3 emissions increase, the LA state shows the largest benefits. Note that the html map may not display well in the jupyter notebook (also jupyter book), so the screen shot of the html figures are shown here.

# %% [markdown]
# <figure>
#   <figcaption>Spatial distribution of PM2.5 changes by applying CCS tech over LA</figcaption>
#   <img src="/Users/yunhalee/Documents/LOCAETA/LOCAETA_AQ/outputs/model_analysis/Screenshot_LA_CCS.png" alt="" width="400"/>
# </figure>
#
#
# <figure>
#   <figcaption>Spatial distribution of PM2.5 changes by applying CCS tech without NH3 emissions increase</figcaption>
#   <img src="/Users/yunhalee/Documents/LOCAETA/LOCAETA_AQ/outputs/model_analysis/Screenshot_LA_CCS_noNH3.png" alt="" width="400"/>
# </figure>
